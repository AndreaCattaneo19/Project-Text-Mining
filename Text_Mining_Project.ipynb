# %%
import pandas as pd
import os
import glob

# %%
file_list = glob.glob(os.path.join(os.getcwd(), "ciao", "*.txt"))

corpus = []

for file_path in file_list:
    with open(file_path) as f_input:
        corpus.append(f_input.read())

print(corpus)
# Out:
# []

# %%
dataframes
# Out:
# []

# %%
# Concatenate all created dataframes into one
df = pd.concat(dataframes)
print(df)
